# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json('logins.json')

# %%
df.head()
# Out:
#                      count
# login_time
# 1970-01-01 20:13:18      1
# 1970-01-01 20:16:10      1
# 1970-01-01 20:16:37      1
# 1970-01-01 20:16:36      1
# 1970-01-01 20:26:21      1

# %%
df = df.set_index('login_time')

# %%
df['count'] = 1

# %%
df_new = df.resample('15T').sum()

# %%
df_new.plot(figsize=(15,6))
plt.xlabel('Date and time')
plt.ylabel('Login count')
plt.title('Login counts per 15 min periods')
# Out:
# Text(0.5, 1.0, 'Login counts per 15 min periods')

# %%
df_new[16:689].plot(subplots=True, figsize=(15,6))
plt.xlabel('Date and time')
plt.ylabel('Login count')
plt.title('Login counts per 15 min periods')
df_new[688:1361].plot(subplots=True, figsize=(15,6))
plt.xlabel('Date and time')
plt.ylabel('Login count')
plt.title('Login counts per 15 min periods')
df_new[1360:2033].plot(subplots=True, figsize=(15,6))
plt.xlabel('Date and time')
plt.ylabel('Login count')
plt.title('Login counts per 15 min periods')
# Out:
# Text(0.5, 1.0, 'Login counts per 15 min periods')

# %%
df_new[5584:6257].plot(subplots=True, figsize=(15,6))
plt.xlabel('Date and time')
plt.ylabel('Login count')
plt.title('Login counts per 15 min periods')
df_new[6256:6929].plot(subplots=True, figsize=(15,6))
plt.xlabel('Date and time')
plt.ylabel('Login count')
plt.title('Login counts per 15 min periods')
df_new[6928:7601].plot(subplots=True, figsize=(15,6))
plt.xlabel('Date and time')
plt.ylabel('Login count')
plt.title('Login counts per 15 min periods')
# Out:
# Text(0.5, 1.0, 'Login counts per 15 min periods')
